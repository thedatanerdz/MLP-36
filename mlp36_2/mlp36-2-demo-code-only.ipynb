# %%
# Load MNIST

from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# Visualize the first input

import matplotlib.pyplot as plt

plt.imshow(X_train[0])

# %%
# Create Adam Optimizer

from tensorflow.keras.optimizers import Adam

opt_1 = Adam(learning_rate=0.001)

# %%
# Base Model (Model 1)

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

model_1 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(10, activation='softmax')])

model_1.compile(optimizer=opt_1, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_1.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4660 - accuracy: 0.8791 - val_loss: 0.3041 - val_accuracy: 0.9152
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3034 - accuracy: 0.9157 - val_loss: 0.2815 - val_accuracy: 0.9217
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2833 - accuracy: 0.9202 - val_loss: 0.2745 - val_accuracy: 0.9228
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2731 - accuracy: 0.9234 - val_loss: 0.2705 - val_accuracy: 0.9246
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2668 - accuracy: 0.9255 - val_loss: 0.2669 - val_accuracy: 0.9250
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2620 - accuracy: 0.9268 - val_loss: 0.2695 - val_accuracy: 0.9245
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2584 - accuracy: 0.9287 - val_loss: 0.2641 - val_accuracy: 0.9277
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2557 - accuracy: 0.9290 - val_loss: 0.2702 - val_accuracy: 0.9226
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2532 - accuracy: 0.9304 - val_loss: 0.2661 - val_accuracy: 0.9259
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2516 - accuracy: 0.9302 - val_loss: 0.2642 - val_accuracy: 0.9278

# %%
# Adding number of parameters (Model 2)

opt_2 = Adam(learning_rate=0.001)

model_2 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(32, activation='relu'),
                     layers.Dense(10, activation='softmax')])

model_2.compile(optimizer=opt_2, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_2.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3611 - accuracy: 0.8985 - val_loss: 0.2175 - val_accuracy: 0.9376
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1885 - accuracy: 0.9454 - val_loss: 0.1635 - val_accuracy: 0.9532
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1486 - accuracy: 0.9568 - val_loss: 0.1484 - val_accuracy: 0.9576
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1260 - accuracy: 0.9629 - val_loss: 0.1401 - val_accuracy: 0.9597
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1091 - accuracy: 0.9672 - val_loss: 0.1227 - val_accuracy: 0.9639
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0973 - accuracy: 0.9711 - val_loss: 0.1235 - val_accuracy: 0.9640
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0879 - accuracy: 0.9736 - val_loss: 0.1173 - val_accuracy: 0.9653
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0802 - accuracy: 0.9755 - val_loss: 0.1175 - val_accuracy: 0.9656
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0734 - accuracy: 0.9783 - val_loss: 0.1161 - val_accuracy: 0.9670
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0679 - accuracy: 0.9794 - val_loss: 0.1131 - val_accuracy: 0.9669

# %%
# Increasing the learning rate (Model 3)

opt_3 = Adam(learning_rate=0.00001)

model_3 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(32, activation='relu'),
                     layers.Dense(10, activation='softmax')])

model_3.compile(optimizer=opt_3, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_3.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 2.0199 - accuracy: 0.3423 - val_loss: 1.6821 - val_accuracy: 0.6144
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.4385 - accuracy: 0.6959 - val_loss: 1.2000 - val_accuracy: 0.7746
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.0673 - accuracy: 0.7885 - val_loss: 0.9142 - val_accuracy: 0.8211
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.8444 - accuracy: 0.8253 - val_loss: 0.7402 - val_accuracy: 0.8446
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.7049 - accuracy: 0.8445 - val_loss: 0.6315 - val_accuracy: 0.8605
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6149 - accuracy: 0.8583 - val_loss: 0.5594 - val_accuracy: 0.8719
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5531 - accuracy: 0.8680 - val_loss: 0.5090 - val_accuracy: 0.8810
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5085 - accuracy: 0.8755 - val_loss: 0.4714 - val_accuracy: 0.8869
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4751 - accuracy: 0.8809 - val_loss: 0.4432 - val_accuracy: 0.8919
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4491 - accuracy: 0.8858 - val_loss: 0.4208 - val_accuracy: 0.8948

# %%
# Greatly add number of parameters (Model 4)

opt_4 = Adam(learning_rate=0.001)

model_4 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(128, activation='relu'),
                     layers.Dense(128, activation='relu'),
                     layers.Dense(10, activation='softmax')])

model_4.compile(optimizer=opt_4, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_4.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2253 - accuracy: 0.9341 - val_loss: 0.1006 - val_accuracy: 0.9691
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0946 - accuracy: 0.9714 - val_loss: 0.0889 - val_accuracy: 0.9711
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0675 - accuracy: 0.9793 - val_loss: 0.0884 - val_accuracy: 0.9736
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0525 - accuracy: 0.9833 - val_loss: 0.0843 - val_accuracy: 0.9731
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0386 - accuracy: 0.9875 - val_loss: 0.0825 - val_accuracy: 0.9764
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0346 - accuracy: 0.9887 - val_loss: 0.0869 - val_accuracy: 0.9740
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0269 - accuracy: 0.9912 - val_loss: 0.0869 - val_accuracy: 0.9763
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0229 - accuracy: 0.9921 - val_loss: 0.1041 - val_accuracy: 0.9731
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.0811 - val_accuracy: 0.9801
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.0887 - val_accuracy: 0.9786

# %%
# Add Regularization / Dropout to reduce overfitting

from tensorflow.keras.regularizers import L2

opt_5 = Adam(learning_rate=0.001)

model_5 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(128, activation='relu', kernel_regularizer=L2(0.001)),
                     layers.Dropout(0.05),
                     layers.Dense(128, activation='relu', kernel_regularizer=L2(0.001)),
                     layers.Dropout(0.05),
                     layers.Dense(128, activation='relu', kernel_regularizer=L2(0.001)),
                     layers.Dropout(0.05),
                     layers.Dense(10, activation='softmax')])

model_5.compile(optimizer=opt_5, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_5.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.5270 - accuracy: 0.9164 - val_loss: 0.3192 - val_accuracy: 0.9598
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3057 - accuracy: 0.9555 - val_loss: 0.2479 - val_accuracy: 0.9666
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2624 - accuracy: 0.9611 - val_loss: 0.2363 - val_accuracy: 0.9672
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2449 - accuracy: 0.9641 - val_loss: 0.2282 - val_accuracy: 0.9672
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2355 - accuracy: 0.9642 - val_loss: 0.2221 - val_accuracy: 0.9684
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2295 - accuracy: 0.9651 - val_loss: 0.2127 - val_accuracy: 0.9707
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2209 - accuracy: 0.9674 - val_loss: 0.1962 - val_accuracy: 0.9743
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2168 - accuracy: 0.9672 - val_loss: 0.2076 - val_accuracy: 0.9694
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2108 - accuracy: 0.9679 - val_loss: 0.1904 - val_accuracy: 0.9730
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2126 - accuracy: 0.9667 - val_loss: 0.2003 - val_accuracy: 0.9706

# %%
# Increase number of epochs

model_5.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2048 - accuracy: 0.9694 - val_loss: 0.1957 - val_accuracy: 0.9716
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2054 - accuracy: 0.9688 - val_loss: 0.2097 - val_accuracy: 0.9669
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2042 - accuracy: 0.9687 - val_loss: 0.1871 - val_accuracy: 0.9744
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1997 - accuracy: 0.9700 - val_loss: 0.1929 - val_accuracy: 0.9715
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2062 - accuracy: 0.9681 - val_loss: 0.1875 - val_accuracy: 0.9749
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1980 - accuracy: 0.9700 - val_loss: 0.1950 - val_accuracy: 0.9695
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1997 - accuracy: 0.9696 - val_loss: 0.1798 - val_accuracy: 0.9745
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1997 - accuracy: 0.9695 - val_loss: 0.1909 - val_accuracy: 0.9719
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1960 - accuracy: 0.9699 - val_loss: 0.2010 - val_accuracy: 0.9709
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1982 - accuracy: 0.9691 - val_loss: 0.1806 - val_accuracy: 0.9742
